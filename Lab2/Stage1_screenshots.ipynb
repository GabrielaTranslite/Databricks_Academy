# %% [markdown]
# # Stage 1

# %% [markdown]
# # Storage account

# %% [markdown]
# ## Creating a storage account - tab 1
#
# ![image_1783775339107.png](./image_1783775339107.png "image_1783775339107.png")

# %% [markdown]
# ## Creating a storage account - tab 2
#
# ![image_1783775161740.png](./image_1783775161740.png "image_1783775161740.png")

# %% [markdown]
# ## Creating a storage account - tab 3
# ![image_1783775242720.png](./image_1783775242720.png "image_1783775242720.png")

# %% [markdown]
# ## Creating a storage account - review tab
# ![image_1783775382722.png](./image_1783775382722.png "image_1783775382722.png")

# %% [markdown]
# # Key Vault

# %% [markdown]
# ## Creating a key vault - tab 1
# ![image_1783775561690.png](./image_1783775561690.png "image_1783775561690.png")

# %% [markdown]
# ## Creating a key vault - tab 2
# ![image_1783775610679.png](./image_1783775610679.png "image_1783775610679.png")

# %% [markdown]
# ## Creating a key vault - tab 3
# ![image_1783775643526.png](./image_1783775643526.png "image_1783775643526.png")

# %% [markdown]
# ## Creating a key vault - review tab
# ![image_1783775665803.png](./image_1783775665803.png "image_1783775665803.png")

# %% [markdown]
# # Databricks Workspace

# %% [markdown]
# ## Creating a Databricks workspace - tab 1
# ![image_1783776138004.png](./image_1783776138004.png "image_1783776138004.png")

# %% [markdown]
# ## Creating a Databricks workspace - tab 2
# ![image_1783775980689.png](./image_1783775980689.png "image_1783775980689.png")

# %% [markdown]
# # Creating a Databricks workspace - review tab
# ![image_1783776159180.png](./image_1783776159180.png "image_1783776159180.png")
