-- %%
--GRANT USE SCHEMA ON SCHEMA dbr_dev.gabrielajaniszews786_bronze TO `8ee90637-2671-4a90-b526-0923930e35f5`;
--GRANT MODIFY, SELECT ON TABLE dbr_dev.gabrielajaniszews786_bronze.zerobus_bronze TO `8ee90637-2671-4a90-b526-0923930e35f5`;

--SHOW GRANTS ON SCHEMA dbr_dev.gabrielajaniszews786_bronze;
--SHOW GRANTS ON TABLE dbr_dev.gabrielajaniszews786_bronze.zerobus_bronze;

SHOW GRANTS ON SCHEMA dbr_dev.gabrielajaniszews786_bronze;
